# %%
import numpy as np
import pandas as pd
import matplotlib as ptl
import matplotlib.pyplot as plot
df = pd.read_csv('all_month.csv',usecols=['depth', 'place'], low_memory=True, nrows=10)




print(df)

xpoints=df.place
ypoints=df.depth 

ax = df.plot.bar(x='place', y='depth')


plot.show()
# Out:
#    depth                          place
# 0   5.00                  western Texas
# 1   0.00                northern Alaska
# 2   8.20   25 km E of Livengood, Alaska
# 3   0.25     5 km NNW of Pāhala, Hawaii
# 4  40.00    21 km NNE of Willow, Alaska
# 5   2.23      3km NW of The Geysers, CA
# 6  84.10  48 km WSW of Cantwell, Alaska
# 7  31.84     7 km ENE of Pāhala, Hawaii
# 8  14.50   14 km SSW of Susitna, Alaska
# 9   9.04     11km SE of Valle Vista, CA
